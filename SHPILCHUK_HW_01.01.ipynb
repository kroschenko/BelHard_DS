# %%
a = int(input("Введите длину: "))
b = int(input("Введите ширину: "))
s=a*b
print("Площадь прямоугольника: ",s)
# Out:
# Введите длину:  2
# Введите ширину:  5
# Площадь такого прямоугольника:  10
